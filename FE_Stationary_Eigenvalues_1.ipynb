# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los autovalores en un array
autovalores = np.array([
    1.204933465e-37,	3.012333746e-37,	3.012333747e-37,	4.819734251e-37,	6.024668091e-37,
	6.024668103e-37,	7.832069279e-37,	7.832069352e-37,	1.024193821e-36,	1.024193836e-36,
	1.084440585e-36,	1.204934097e-36,	1.204934138e-36, 1.506168095e-36,	1.506168112e-36,
	1.566414872e-36,	1.5664149e-36,	1.747155503e-36,	1.747155571e-36,	1.927896213e-36
])

alpha = autovalores[0]/2
E_div_alpha = autovalores/alpha #he normalizado los autovalores
indices = np.arange(0, len(autovalores), 1)
plt.ylabel(r'$2mE/E_{0}\hbar^2$')
plt.scatter(indices, E_div_alpha)
[plt.axhline(nx**2 + ny**2,color='r') for nx in range(1,5) for ny in range(1,5)]
plt.show()
